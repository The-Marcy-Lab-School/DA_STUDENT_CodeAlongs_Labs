# %% [markdown]
# # Final Practice Gauntlet: Everything, Plus Previews: Lambda & Plotly
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Retrieve every skill from this module, unprompted, under quick-fire pressure
# - Recognize lambda syntax and what a dashboard adds beyond a static chart
#
# **Skills:** lambda, dashboard

# %% [markdown]
# ## Scenario
#
# No new graded material today. Six rounds, cumulative across the whole module — stats and charts, missing data and cleaning, pattern-mining, clarifying questions, AI critique, and stakeholder writing — unannounced in advance, the same format a real technical screening interview uses. Then two quick, honest previews of what's coming later in the program.

# %% [markdown]
# ## Sorting Species by Mean Mass, One Line
#
# *⚠️ Not auto-validated: A light syntax preview, not a graded rep — nothing here needs auto-validation.*
#
# *Context: The lambda here is a tiny unnamed function — given one item, it returns that item's second value, used just to tell sorted() what to sort by.*
#
# *Input:*

# %%
# NOTE: not auto-validated - A light syntax preview, not a graded rep — nothing here needs auto-validation.
items = [("Adelie", 3700.7), ("Chinstrap", 3733.1), ("Gentoo", 5076.0)]
sorted(items, key=lambda pair: pair[1], reverse=True)
