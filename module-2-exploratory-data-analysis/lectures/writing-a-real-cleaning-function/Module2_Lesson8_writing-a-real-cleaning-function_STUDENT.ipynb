# %% [markdown]
# # Writing a Real Cleaning Function
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Write a reusable cleaning function instead of repeating inline fixes
# - Tell a genuinely reusable function apart from a renamed one-off script
#
# **Skills:** reusable function

# %% [markdown]
# ## Scenario
#
# A real, messy column — raw timestamp strings that can't be sorted or filtered by date until they're actually parsed. You'll write one real function to fix it, then prove it's genuinely reusable by applying it to a second real column, unchanged.

# %% [markdown]
# ## Fixing It Inline, Twice
#
# *Context: This works — both new columns are real dates. That's exactly what makes this pattern tempting to keep using.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas, reload df from "../../data/earthquakes.csv"
# TODO: parse "time" into event_date, inline, no function
# TODO: parse "updated" into updated_date, inline, no function

# %% [markdown]
# ## One Real Function, Called Twice
#
# *Context: Not a single line of the actual parsing logic changed between the two calls — genuine reuse, not just two functions that happen to look similar.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: write one reusable function that turns a raw timestamp
# string column into real dates
# TODO: call it on df["time"], then again on df["updated"]
