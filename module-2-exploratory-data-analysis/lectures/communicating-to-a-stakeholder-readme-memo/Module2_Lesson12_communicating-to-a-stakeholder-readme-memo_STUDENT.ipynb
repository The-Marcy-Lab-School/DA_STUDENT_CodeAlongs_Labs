# %% [markdown]
# # Communicating to a Stakeholder: README & Memo
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Rewrite a project README as a real stakeholder-facing landing page
# - Write a data-quality memo a non-technical reader can act on
#
# **Skills:** stakeholder-facing

# %% [markdown]
# ## Scenario
#
# Every finding so far has lived in a notebook, written for yourself. Today that flips — the same findings get rewritten twice, once as a README a stakeholder actually reads, and once as a memo that restates the answer and names what's still worth checking.

# %% [markdown]
# ## Verify the Number, One More Time
#
# *Context: 20.0%, 11.7%, and 17.2% — the exact numbers this deck's own README/memo examples cite, reconfirmed fresh.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas, reload df, drop rows missing "sex"
# TODO: recompute the real male/female mass-gap percentage

# %% [markdown]
# ## Markdown Image Syntax
#
# *Language: markdown - not auto-validated by the Code Execution Validator, review manually.*
#
# *Context: The alt text describes the chart for real — never just a filename or "chart.png".*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
<!-- TODO: embed images/mass_by_species.png with real alt text -->
<!-- TODO: state the finding in one plain sentence below it -->

# %% [markdown]
# ## Memo Skeleton
#
# *Language: markdown - not auto-validated by the Code Execution Validator, review manually.*
#
# *Context: 4 required pieces, every memo: domain/stakeholder, plain-language answer, checkable questions, a trust connection.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
<!-- TODO: name the domain and stakeholder -->
<!-- TODO: restate the answer in plain language -->
<!-- TODO: list 2 checkable questions -->
<!-- TODO: connect one question to trust in the answer -->
