# %% [markdown]
# # Missing Data: Drop, Fill, or Flag
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Decide whether to drop, fill, or flag missing data, and justify the choice
# - Apply mean, median, mode, and forward-fill, and explain when each fits
#
# **Skills:** drop, fill, flag, forward-fill

# %% [markdown]
# ## Scenario
#
# Real data has real gaps — 344 penguins, several genuinely missing values, each one a real decision. Drop, fill, or flag, and which fill technique, if any — today's the first time any lesson in this program has actually taught how to decide.

# %% [markdown]
# ## Reloading the Data
#
# *Context: A fresh notebook session starts with nothing in memory — the same reload step from earlier lessons.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas as pd


# TODO: read "../../data/penguins.csv" into df
# TODO: check missing values per column

# %% [markdown]
# ## Dropping the Genuinely Empty Rows
#
# *Context: Dropping on `bill_length_mm` catches both fully-empty rows, since all 4 measurement columns are missing on the exact same 2 rows.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: drop rows where bill_length_mm is missing
# TODO: check the new shape

# %% [markdown]
# ## Flagging Instead of Guessing
#
# *Context: `.isna()` itself returns True/False — assigning it straight to a new column is the flag, no separate step needed.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: .copy() cleaned first, to avoid SettingWithCopyWarning
# TODO: create sex_unknown = True wherever sex is missing
# TODO: count how many rows are flagged

# %% [markdown]
# ## Four Fill Techniques, One Missing Value
#
# *Context: 7 days of attendance, one day missing — the real question is which of these 4 answers actually fits.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: build attendance as a Series: 10, 10, 10, 12, 14, None, 90
# TODO: print the mean-fill, median-fill, mode-fill, and
# forward-fill value for the missing spot (index 5)
