# %% [markdown]
# # Chart Best Practices
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Spot a misleading chart: A truncated axis, or hidden outliers
# - Apply real labeling and accessibility practices to any chart
#
# **Skills:** truncated axis, chart junk

# %% [markdown]
# ## Scenario
#
# Picking the right chart type isn't enough — a bar chart can lie with its own y-axis, and a boxplot can hide the exact outliers you found earlier. Today's real, verified examples of both, plus labeling and accessibility practices that apply to every chart from here forward.

# %% [markdown]
# ## A Boxplot, With showfliers=False
#
# *Context: The upper fence is the boxplot's own cutoff for "normal" — anything past it is a real outlier, whether or not the chart chooses to show it.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas and matplotlib.pyplot
# TODO: read "../../data/earthquakes.csv" into df
# TODO: compute Q1 and Q3 for depth, print the upper fence
# TODO: print the real max depth
