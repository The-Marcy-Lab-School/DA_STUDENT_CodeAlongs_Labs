# %% [markdown]
# # Exploratory vs. Explanatory: Two Kinds of Charts
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Explain the difference between an exploratory chart and an explanatory chart
# - Choose the right chart type by naming what's actually being compared
#
# **Skills:** exploratory chart, explanatory chart

# %% [markdown]
# ## Scenario
#
# Two ideas today, both new: Exploratory charts are for you, messy and fast, finding a pattern; explanatory charts are for a stakeholder, polished and chosen on purpose. Then a real decision framework for picking the right chart type — modeled live, on real earthquake data, not just described.

# %% [markdown]
# ## Depth vs. Magnitude
#
# *Context: 2,107 real January 2024 earthquakes, magnitude 2.5+ — a new dataset, not the penguins from earlier this module.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas and matplotlib.pyplot
# TODO: read "../../data/earthquakes.csv" into df
# TODO: check the correlation between mag and depth
