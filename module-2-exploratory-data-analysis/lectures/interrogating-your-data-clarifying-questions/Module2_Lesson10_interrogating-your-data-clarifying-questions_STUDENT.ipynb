# %% [markdown]
# # Interrogating Your Data: Clarifying Questions
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Evaluate a dataset's collection process before trusting a pattern found in it
# - Pose specific, checkable clarifying questions — not generic ones
#
# **Skills:** checkable question

# %% [markdown]
# ## Scenario
#
# Yesterday's pattern survived a confound check — but that's not the same as trusting the data itself. With a partner, you'll use a real peer-review checklist to interrogate where the penguin data actually came from, and practice telling a specific, checkable question apart from a generic one.

# %% [markdown]
# ## How Many Penguins, Per Island?
#
# *Context: Torgersen has far fewer rows than Biscoe or Dream — worth asking why, not just noting it.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas, reload df from "../../data/penguins.csv"
# TODO: count how many rows belong to each island

# %% [markdown]
# ## Are the Missing Values Spread Evenly?
#
# *Context: Chinstrap has zero missing sex values; Adelie has 6 and Gentoo has 5 — not spread evenly.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: group by species, count missing "sex" values per group
