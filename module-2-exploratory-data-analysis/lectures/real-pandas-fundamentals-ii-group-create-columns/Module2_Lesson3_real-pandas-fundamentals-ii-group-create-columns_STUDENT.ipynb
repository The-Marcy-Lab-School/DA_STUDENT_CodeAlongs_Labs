# %% [markdown]
# # Real Pandas Fundamentals II: Group & Create Columns
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Summarize a numeric column by category with .groupby()
# - Create a new derived column, and avoid the SettingWithCopyWarning gotcha
#
# **Skills:** groupby, aggregation

# %% [markdown]
# ## Scenario
#
# Same 344 penguins as yesterday. Two new moves: summarizing a number by category instead of scrolling through every row yourself, and building a new column instead of recomputing the same formula over and over. Both are the last real pandas gap before the project can start.

# %% [markdown]
# ## Reloading Yesterday's Data
#
# *Context: Same load from yesterday — a new notebook session starts with nothing in memory, even if yesterday's code looks familiar.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas as pd


# TODO: read "../../data/penguins.csv" into a DataFrame called df
# TODO: check its shape

# %% [markdown]
# ## Grouping by Species
#
# *Context: `.groupby("species")` alone does nothing visible yet — it's the `["body_mass_g"].mean()` after it that actually produces a result.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: group df by "species"
# TODO: pull out body_mass_g, and take the mean of each group
# TODO: round to 1 decimal place

# %% [markdown]
# ## Multiple Summaries With .agg()
#
# *Context: `.agg([...])` takes a list of summary names and computes every one, per group, in a single pass — no need to repeat `.groupby()` three separate times.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: group df by "species", pull out body_mass_g
# TODO: use .agg() to get count, mean, AND median at once
# TODO: round to 1 decimal place

# %% [markdown]
# ## Deriving bill_ratio
#
# *Context: The new column is computed for all 344 rows in one line — no loop, no repeating the formula anywhere else.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: create a new column bill_ratio = bill_length_mm / bill_depth_mm
# TODO: show species and bill_ratio for the first 3 rows
