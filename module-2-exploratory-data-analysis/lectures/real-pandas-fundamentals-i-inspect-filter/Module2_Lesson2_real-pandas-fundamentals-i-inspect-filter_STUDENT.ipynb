# %% [markdown]
# # Real Pandas Fundamentals I: Inspect & Filter
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Load a real CSV and inspect its shape, dtypes, and missing values
# - Filter rows with one condition and with combined conditions
#
# **Skills:** DataFrame, dtype, boolean filter

# %% [markdown]
# ## Scenario
#
# Real data, real syntax, for the first time this module: 344 penguins, 3 species, real missing values. You'll load it, inspect what's actually in it, and filter down to just the rows you care about — the same two moves every real analysis starts with.

# %% [markdown]
# ## Loading the Real Data
#
# *Context: `penguins.csv` sits two folders up from this notebook, in a shared `data/` folder — real Palmer Station penguin measurements, not the project's own data.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas as pd


# TODO: read "../../data/penguins.csv" into a DataFrame called df
# TODO: check its shape

# %% [markdown]
# ## Checking dtypes
#
# *Context: `object` means text, `float64` means a decimal number, `int64` means a whole number — pandas guesses this from the file, it doesn't always guess right.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: check every column's dtype

# %% [markdown]
# ## Checking for Missing Values
#
# *Context: `.isna()` marks every missing cell `True`, then `.sum()` adds those up per column — real missing data, not injected for this demo.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: count how many missing values are in each column

# %% [markdown]
# ## Filtering on One Condition
#
# *Context: `df["species"] == "Gentoo"` builds a True/False value for every row first — `df[...]` then keeps only the `True` ones.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: keep only rows where species is "Gentoo"
# TODO: check how many rows that leaves

# %% [markdown]
# ## Combining Two Conditions
#
# *Context: `&` means AND for filtering — parentheses around each condition are required, not optional style.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: keep only rows where species is "Adelie" AND
# island is "Biscoe" -- use & and wrap each condition in parens
# TODO: check how many rows that leaves

# %% [markdown]
# ## Sorting by a Column
#
# *Context: `ascending=False` means biggest first — `.head(3)` limits the printed output to the top 3 rows, not the whole sorted table.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: sort df by body_mass_g, heaviest first
# TODO: show just species and body_mass_g, top 3 rows
