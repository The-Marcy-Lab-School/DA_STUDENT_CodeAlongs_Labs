# %% [markdown]
# # Mining a Pattern, With a Peer
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Mine a real dataset for a non-obvious pattern worth escalating to a stakeholder
# - Judge whether mean or median more honestly represents it
#
# **Skills:** non-obvious pattern

# %% [markdown]
# ## Scenario
#
# 344 raw penguin records, 333 once today's code-along drops the rows missing a sex value, one pattern already known (species and mass), and at least one more waiting to be found. With a partner, you'll segment the data, compare groups, and decide which statistic actually backs up what you find — the first real pattern-mining rep this module.

# %% [markdown]
# ## Segmenting by Two Categories at Once
#
# *Context: Grouping by two columns at once splits into every real species/sex combination, not just one or the other.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas, reload df from "../../data/penguins.csv"
# TODO: clean df so missing sex values don't split the groups below
# TODO: group by BOTH species and sex, get mean/median/std of body_mass_g, rounded

# %% [markdown]
# ## Island Looks Like It Predicts Mass
#
# *Context: Biscoe averages over 1,000g heavier than Dream or Torgersen — a real, checkable gap.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: group by island, mean body_mass_g, rounded

# %% [markdown]
# ## Which Species Live on Which Island?
#
# *Context: Biscoe is the only island with any Gentoo penguins at all — the heaviest species in the whole dataset.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: group by BOTH island and species, count rows in each
