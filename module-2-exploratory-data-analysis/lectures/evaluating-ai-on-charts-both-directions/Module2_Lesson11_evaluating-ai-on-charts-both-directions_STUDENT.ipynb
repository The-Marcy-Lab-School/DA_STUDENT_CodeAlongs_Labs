# %% [markdown]
# # Evaluating AI on Charts, Both Directions
#
# **Module 2: Exploratory Data Analysis**
#
# **Learning Objectives:**
# - Catch an AI's subtle misreading of a real chart's shape
# - Catch an AI's own flawed chart-type suggestion
#
# **Skills:** AI critique

# %% [markdown]
# ## Scenario
#
# An AI can describe a chart fluently while still getting its shape wrong — and it can suggest a chart type that doesn't actually fit the question. Today you'll catch both, live, on real earthquake data, before the project asks you to do it on your own.

# %% [markdown]
# ## Depth: Mean vs. Median
#
# *Context: Mean depth is 63.0 km; median depth is 11.73 km — a huge gap, the real signature of right skew.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: import pandas, reload df from "../../data/earthquakes.csv"
# TODO: compare mean and median depth

# %% [markdown]
# ## Magnitude: Mean vs. Median
#
# *Context: Mean magnitude is 3.93; median magnitude is 4.2 — close together, unlike depth.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: compare mean and median magnitude
