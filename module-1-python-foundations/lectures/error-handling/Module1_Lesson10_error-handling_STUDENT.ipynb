# %% [markdown]
# # Error Handling
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Write a try/except block that catches a real error instead of crashing
# - Recognize common Python error types and what triggers each one
# - Decide when to check a value first vs. just trying it and catching failure
#
# **Skills:** exception, try/except, ValueError, TypeError, NameError, IndexError, KeyError

# %% [markdown]
# ## Scenario
#
# The last lesson's validate_batch checked a field's shape before trusting it. Today's question is different: what do you do when you just try the risky operation directly, and it fails? try/except is Python's real answer — attempt it, and handle the failure exactly where it happens, without crashing the rest of the script.

# %% [markdown]
# ## Documentation
#
# - Catching the Crash: https://docs.python.org/3/tutorial/errors.html#handling-exceptions

# %% [markdown]
# ## Watch This Crash
#
# *Note: this cell is expected to raise `ValueError` - that's the teaching point, not a bug.*
#
# *Context: This is deliberately left unhandled — the point is seeing the real crash before fixing it. The last line never runs at all.*
#
# *Input:*

# %%
quantity = "abc"
count = int(quantity)
print("Converted:", count)

# %% [markdown]
# ## Catching the Crash
#
# *Context: `except ValueError:` only catches THAT specific error — naming the exact exception type is deliberate, not optional boilerplate.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: set quantity = "abc"
# TODO: inside a try block, convert it to int and print "Converted:"
# plus the result
# TODO: in an except ValueError block, print "That's not a valid
# number."

# %% [markdown]
# ## Putting It Together: Two except Clauses
#
# *Context: A line with too few fields raises IndexError the moment fields[2] is reached — no separate field-count check needed at all this time, the try/except handles both failure types, each with its own except clause and its own message.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define validate_batch(lines)
# TODO: for each line, inside a try block: split on ",", print
# "OK:" with fields[1] and int(fields[2])
# TODO: add an except IndexError clause printing "Bad format:" + line
# TODO: add an except ValueError clause printing "Bad quantity:" + line

# TODO: create a list called lines with these 3 strings:
# "ADD,Chess,4", "REMOVE,Uno", "ADD,Dice,two"
# TODO: call validate_batch(lines)
