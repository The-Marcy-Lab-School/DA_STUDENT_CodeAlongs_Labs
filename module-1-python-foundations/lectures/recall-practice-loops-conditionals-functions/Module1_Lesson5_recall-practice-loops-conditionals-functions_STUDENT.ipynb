# %% [markdown]
# # Recall & Practice: Loops, Conditionals, Functions
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Retrieve loop, conditional, and function syntax from memory, unprompted
# - Trace and debug realistic loop/function code the way an interviewer would test it

# %% [markdown]
# ## Scenario
#
# No new material today — just you, testing your own memory. You'll trace, debug, and write small loop/conditional/function snippets from recall alone, the same way an interviewer hands you a snippet and asks "what does this print?" or "what's wrong with this?"

# %% [markdown]
# ## Loop + Conditional + Function, Together
#
# *Context: A generic example on purpose — not tied to any project scenario, but this exact shape (a loop wrapping a conditional, inside a function) is the project's own validate_line/process_transactions shape.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define count_passing(scores, threshold) that returns how
# many scores are >= threshold, using a loop + a conditional
# inside a function


# TODO: call it with [55, 82, 91, 40, 76] and threshold 70, and
# print the result
