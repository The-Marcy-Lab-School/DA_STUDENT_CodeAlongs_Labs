# %% [markdown]
# # Big-O in Practice: Linear Scan vs. Dict Lookup, With a Partner
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Write both a linear-scan function and a dict-keyed lookup over a list of class objects
# - With a partner, determine each approach's Big-O and explain why the dict approach scales better
#
# **Skills:** linear-scan search, dict-keyed lookup

# %% [markdown]
# ## Scenario
#
# You already know the intuition (some lookups stay fast, some don't) and the syntax (list vs. dict). Today combines both, with a partner, over a list of real class objects — write a linear-scan search and a dict-keyed search for the exact same data, then determine and defend each one's Big-O.

# %% [markdown]
# ## Setup: A Class and Its Objects
#
# *Context: This is a new demo domain on purpose — a fresh scenario, not the board-game or library-tool class from earlier lessons.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define SupplyItem with __init__ storing name, count,
# department


# TODO: create a list called supplies with 4 SupplyItem objects
# of your own choosing

# %% [markdown]
# ## Search 1: Linear Scan
#
# *Context: Worst case, this checks every single item before finding a match — or before confirming there isn't one.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define find_by_name_linear(supplies, name) that loops over
# supplies and returns the item whose .name matches, or None if
# nothing matches


# TODO: call it looking for "Tape", then print the result's name
# and count

# %% [markdown]
# ## Search 2: Dict-Keyed Lookup
#
# *Context: `{item.name: item for item in supplies}` is a dict comprehension — same idea as a list comprehension, just building key-value pairs instead of a flat list.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: build supplies_by_name as a dict comprehension keyed by
# each item's .name, valued as the item itself


# TODO: look up "Tape" with .get(), then print its name and count
