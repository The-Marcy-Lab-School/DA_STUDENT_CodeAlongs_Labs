# %% [markdown]
# # Magic Methods — What __init__/__str__/__repr__ Actually Mean
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Add __str__ and __repr__ to a class, extending the last lesson's template
# - Explain which one Python actually uses, and when
#
# **Skills:** magic method, __str__, __repr__

# %% [markdown]
# ## Scenario
#
# The last lesson's class works, but printing an object right now shows something genuinely useless. Today, with the same partner, extends that exact class with two more special methods — not a new topic, the same template, one more layer.

# %% [markdown]
# ## Documentation
#
# - Step 1: Add __str__: https://docs.python.org/3/reference/datamodel.html#object.__str__

# %% [markdown]
# ## Watch This: The Default Is Ugly
#
# *Context: That `<__main__.BoardGame object at 0x...>` text is Python's own last-resort default — it exists, but it tells you nothing about the actual game.*
#
# *Input:*

# %%
class BoardGame:
    def __init__(self, title, players_available, category):
        self.title = title
        self.players_available = players_available
        self.category = category

connect4 = BoardGame("Connect Four", 4, "Strategy")
print(connect4)

# %% [markdown]
# ## Step 1: Add __str__
#
# *Context: `print(connect4)` now calls `__str__` automatically — you never call `connect4.__str__()` by hand, Python does it for you the moment you print an object.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: keep __init__ from before
# TODO: add __str__(self) that returns
# f"{self.title}, {self.players_available} left"


# TODO: create connect4 again, then print(connect4)

# %% [markdown]
# ## Step 2: Add __repr__ Too
#
# *Context: This cell only redefines the class — no output yet on purpose. The next cell actually tests it.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: keep __init__ and __str__ from Step 1
# TODO: add __repr__(self) that returns f"BoardGame('{self.title}')"

# %% [markdown]
# ## Now Test repr()
#
# *Input:*

# %%
connect4 = BoardGame("Connect Four", 4, "Strategy")
print(repr(connect4))

# %% [markdown]
# ## The Real Gotcha: A List of Objects
#
# *Context: Both lines print the same two objects — the difference is entirely about HOW each one gets shown, not which objects exist.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: create connect4 and uno again
# TODO: print(connect4) alone
# TODO: print a list containing both: [connect4, uno]
