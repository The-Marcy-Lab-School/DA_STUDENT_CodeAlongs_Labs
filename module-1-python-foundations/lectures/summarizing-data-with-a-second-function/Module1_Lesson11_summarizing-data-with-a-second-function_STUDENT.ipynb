# %% [markdown]
# # Summarizing Data With a Second Function
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Write a second function that summarizes already-validated data
# - Keep validating and summarizing as two separate, single-job functions
#
# **Skills:** summarizing

# %% [markdown]
# ## Scenario
#
# The last lesson's function decided whether each line was valid. Today's function has a different job entirely: given data that's already been validated, summarize it — a formatted listing, plus an alert list for anything running low. Same template shape as before, lighter scaffolding this time.

# %% [markdown]
# ## Step 1: A Formatted Listing
#
# *Context: This list is already assumed valid — no format or type checks here, that job is finished before this function ever runs.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: create a list called games of (title, players) tuples:
# ("Chess", 4), ("Checkers", 6), ("Clue", 1), ("Uno", 8)


# TODO: define summarize_batch(games) that prints one formatted
# line per game: "{title}: {players} available"


# TODO: call summarize_batch(games)

# %% [markdown]
# ## Step 2: Add a Low-Availability Alert
#
# *Context: This is a second, separate loop over the same list — not a change to the first one. summarize_batch now has two things to report, not two jobs; both are still "summarize," not "validate."*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: keep Step 1's listing loop
# TODO: print a blank line, then "Low availability:"
# TODO: loop over games again; if players < 3, print
# "  {title} ({players})"
# TODO: call summarize_batch(games)

# %% [markdown]
# ## Step 3: Add a Total Count
#
# *Context: `len(games)` counts the list itself — no loop needed for a simple total, just the built-in length.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: keep Step 2's listing and alert loops
# TODO: print a blank line, then f"{len(games)} games total"
# TODO: call summarize_batch(games)
