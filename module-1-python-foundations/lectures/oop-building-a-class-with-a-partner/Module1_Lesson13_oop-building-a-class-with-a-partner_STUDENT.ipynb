# %% [markdown]
# # OOP: Building a Class With a Partner
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Define a class with __init__, attributes, and a method, following a worked template
# - Instantiate multiple objects and confirm each one stores its own data independently
#
# **Skills:** class, object, attribute, method, self

# %% [markdown]
# ## Scenario
#
# Every value so far has been a single number, string, or a plain list or dict of them. Today asks a different question: what happens when you want to bundle related data AND the actions that belong to it together, as one real thing? With a partner, following a worked template — today isn't the independent design test, that comes later.

# %% [markdown]
# ## Step 1: __init__ and Attributes
#
# *Context: `__init__` runs automatically the instant `BoardGame(...)` is called — it's never called by name directly. `self.title = title` is what actually stores the value ON this specific object, not just in a local variable that disappears.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define class BoardGame with __init__(self, title,
# players_available, category) that stores all three as
# self.title, self.players_available, self.category


# TODO: create connect4 = BoardGame("Connect Four", 4, "Strategy")
# TODO: print connect4.title, then print connect4.players_available

# %% [markdown]
# ## Step 2: Add a Method
#
# *Context: `connect4.is_low_stock()` — no arguments passed at the call site, but `self` is filled in automatically as `connect4` itself. You never pass `self` by hand.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: keep Step 1's __init__
# TODO: add a method is_low_stock(self) that returns
# self.players_available < 3


# TODO: create connect4 again, then print connect4.is_low_stock()

# %% [markdown]
# ## Step 3: Prove Independent Storage
#
# *Context: Both objects came from the exact same class, but changing connect4's own attribute has zero effect on uno's — each object's attributes live in that object alone, not shared or linked in any way.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: create connect4 = BoardGame("Connect Four", 4, "Strategy")
# TODO: create uno = BoardGame("Uno", 8, "Party")


# TODO: set connect4.players_available = 1
# TODO: print connect4.is_low_stock(), then print uno.is_low_stock()
