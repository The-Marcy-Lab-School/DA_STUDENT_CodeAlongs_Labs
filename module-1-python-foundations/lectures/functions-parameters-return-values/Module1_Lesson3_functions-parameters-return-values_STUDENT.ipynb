# %% [markdown]
# # Functions, Parameters & Return Values
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Define a function with parameters and a return value, and call it correctly
# - Explain why splitting code into functions makes it easier to test and reuse
#
# **Skills:** function, parameter, argument, return value

# %% [markdown]
# ## Scenario
#
# Every project function you'll write this module — reading a file, checking a value, summarizing a list — is the same basic shape: some input goes in, something happens, a result comes back out. Today you'll practice that shape on tiny examples, long before the project asks you to write five of them working together.

# %% [markdown]
# ## Define and Call, Live
#
# *Context: A generic example on purpose — not tied to any project scenario.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define a function named greet that prints a welcome
# message, then call it twice

# %% [markdown]
# ## Parameters, Live
#
# *Context: A generic example on purpose — not tied to any project scenario.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: add a name parameter to greet, and print a
# personalized welcome message for each of 2 names

# %% [markdown]
# ## Return, Live
#
# *Context: A generic example on purpose — not tied to any project scenario.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: write double(n) using return (not print), then use
# its result in an expression - add 1 to it and print that
