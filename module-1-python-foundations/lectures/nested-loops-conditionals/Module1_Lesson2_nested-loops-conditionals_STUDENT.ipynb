# %% [markdown]
# # Nested Loops & Conditionals
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Trace nested loops and state exactly how many times the inner body runs
# - Trace nested conditionals and state which branch actually executes
#
# **Skills:** nested loop, nested conditional

# %% [markdown]
# ## Scenario
#
# Yesterday's loops and conditionals only ever checked one thing at a time. Real data isn't that simple — a grid has rows AND columns, and a single transaction might need one check to know what KIND of thing it is, then a second check to know if it's actually valid. Today you'll practice nesting both, on tiny examples, before the project asks for it on real data.

# %% [markdown]
# ## Nested Loop, Live
#
# *Context: A generic row/col example on purpose — not tied to any project scenario.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: write a nested loop that prints every (row, col)
# pair for row in range(2) and col in range(3)

# %% [markdown]
# ## Nested Conditional, Live
#
# *Context: This exact two-level check — operation type, then value — is what the project's `validate_line` function needs.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: check operation first; if it's "ADD", nest a second
# check confirming quantity is greater than 0
operation = "ADD"
quantity = -5

# %% [markdown]
# ## Putting It Together: Loop + Nested Conditional
#
# *Context: A miniature version of the project's real `validate_line` function — a loop wrapping a nested conditional.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: loop over transactions; for each line, split it into
# operation and amount, then nest the ADD/quantity check
# from the previous slide inside the loop
transactions = ["ADD 10", "REMOVE 3", "ADD -5"]
