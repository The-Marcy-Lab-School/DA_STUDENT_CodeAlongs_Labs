# %% [markdown]
# # Writing Your First Validation Function, From Scratch
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Follow a step-by-step template to write a function that validates a list of transaction-like strings
# - Use enumerate() to report exactly which line failed, not just that something did
#
# **Skills:** batch file, validation, enumerate()

# %% [markdown]
# ## Scenario
#
# You know loops, conditionals, and functions as separate pieces. Today they combine into one real, useful function: given a list of raw text lines, decide which ones are valid and which ones aren't — and say exactly which line, not just "something's wrong." This is the actual shape of the function the project grades, built step by step, on data that isn't the project's own.

# %% [markdown]
# ## Documentation
#
# - Step 4: Add enumerate(): https://docs.python.org/3/library/functions.html#enumerate

# %% [markdown]
# ## Step 1: Just Look at the Data
#
# *Context: This is a board-game shipment log — deliberately not the project's own scenario. Two of these five lines are already broken on purpose: one has too few fields, one has a non-numeric value where a number belongs.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: create a list called lines with these 5 strings:
# "ADD,Chess,4", "ADD,Checkers,two", "ADD,Uno", "" (empty), "ADD,Clue,6"


# TODO: loop over lines and print each one

# %% [markdown]
# ## Step 2: Check Each Line's Shape
#
# *Context: `.split(",")` turns a string into a list, cutting at every comma — "ADD,Chess,4" becomes `["ADD", "Chess", "4"]`, a list of 3 items.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: loop over lines
# TODO: split each line on "," into a variable called fields
# TODO: if fields has exactly 3 items, print "Looks valid:" and the line
# TODO: otherwise, print "Wrong number of fields:" and the line

# %% [markdown]
# ## Step 3: Wrap It in a Real Function
#
# *Context: Nothing about the logic changed — the exact same loop and conditional just moved inside a function, so it can be called on any list of lines, not just this one.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define validate_batch(lines) — move Step 2's loop and
# conditional inside it


# TODO: call validate_batch(lines)

# %% [markdown]
# ## Step 4: Add enumerate()
#
# *Context: `start=1` matters — enumerate() counts from 0 by default, but a human reading a file counts its first line as line 1, not line 0.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: change the loop to "for line_number, line in
# enumerate(lines, start=1):"
# TODO: update both print statements to use f"Line {line_number}: ..."
# instead of printing the line's text

# %% [markdown]
# ## Putting It Together: Both Checks at Once
#
# *Context: `.isdigit()` returns True only if every character is a digit — the standard way to check a string looks like a whole number before trusting it. `action, title, players = fields` unpacks the 3-item list into three named variables in one line, the same tuple-unpacking shape from the data-structures lesson. `enumerate(lines, 1)` and `enumerate(lines, start=1)` do exactly the same thing — start is just being passed positionally here instead of by name.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define validate_batch(lines) using enumerate(lines, 1)
# TODO: if len(fields) != 3, report "bad format"
# TODO: elif fields[2] isn't all digits (.isdigit()), report
# "bad players"
# TODO: else, unpack fields into action, title, players and report
# "OK, {title}"
