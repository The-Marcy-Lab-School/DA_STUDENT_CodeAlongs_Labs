# %% [markdown]
# # Local vs. Global Variables & Scope
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Explain the difference between a local and a global variable
# - Explain why relying on globals makes a function harder to test and reuse than using parameters
#
# **Skills:** local variable, global variable, scope

# %% [markdown]
# ## Scenario
#
# Yesterday's functions took input through parameters and sent a result back through return. Today's question is about everything in between — once a variable exists, where can you actually use it? Every project function needs to work from its own parameters, not variables it secretly reaches outside itself for — today is the first rep of why that distinction matters.

# %% [markdown]
# ## Local Scope, Live
#
# *Note: this cell is expected to raise `NameError` - that's the teaching point, not a bug.*
#
# *Context: A generic example on purpose — not tied to any project scenario.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define make_total() with a local variable total set
# to 100, returning it, then try printing total outside the
# function and watch what happens

# %% [markdown]
# ## Reading a Global, Live
#
# *Context: A generic example on purpose — not tied to any project scenario.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define tax_rate as a global, then write
# price_with_tax(price) that reads it without taking it as
# a parameter

# %% [markdown]
# ## Refactor: Global to Parameter
#
# *Context: The same function from earlier, now with the dependency made explicit.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: rewrite price_with_tax so tax_rate is a parameter
# instead of a global it secretly reads
tax_rate = 0.08
