# %% [markdown]
# # Control Flow & Conditionals
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Trace short, already-written loop/conditional snippets and state their exact output without running them
# - Define iteration, conditional, and loop body in your own words
#
# **Skills:** conditional, loop, iteration, loop body, range()

# %% [markdown]
# ## Scenario
#
# You've got the vocabulary from Module 0 — you know what a variable and a data type are. Today that vocabulary starts doing something: making decisions and repeating work, the same way a real program has to. No project pressure yet, no class to design — just reading code closely enough to say exactly what it'll do before you run it, the same skill an interviewer tests when they hand you a snippet and ask "what does this print?"

# %% [markdown]
# ## If/Elif/Else, Live
#
# *Context: A generic example on purpose — not tied to any project scenario.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: set temperature to any number, then write the
# if/elif/else check yourself before revealing the answer
temperature = 71

# %% [markdown]
# ## For Loop, Live
#
# *Context: A generic example on purpose — not tied to any project scenario.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: write a for loop that prints every value in scores
scores = [88, 92, 75, 100]

# %% [markdown]
# ## range() Generates Numbers to Loop Over
#
# *Context: `range(5)` produces `0, 1, 2, 3, 4` — five values, starting at 0, stopping before 5.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: use range() to print the numbers 0 through 4

# %% [markdown]
# ## While Loop, Live
#
# *Context: A generic example on purpose — not tied to any project scenario.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: write a while loop that prints 0, 1, 2, 3 -
# think carefully about the condition
count = 0

# %% [markdown]
# ## Loop and Conditional, Together
#
# *Context: This exact shape — loop wrapping a conditional — is what a real validation function needs later this module.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: loop over scores; for each one, print "great job"
# if it's 90 or above, otherwise print "keep practicing"
scores = [88, 92, 75, 100]
