# %% [markdown]
# # Recall & Practice: Functions, Validation, try/except, Serialization
#
# **Module 1: Python Foundations**
#
# **Learning Objectives:**
# - Retrieve serialization, validation, error-handling, and summarizing from memory, unprompted
# - Write a function that accepts a flexible number of arguments with *args and **kwargs
#
# **Skills:** *args, **kwargs

# %% [markdown]
# ## Scenario
#
# Most of today is retrieval practice on the last four lessons — serialization, validation, error handling, and summarizing — the same way you'd need to explain them cold in an interview. Then one genuinely new idea: what happens when a function doesn't know in advance how many arguments it'll get?

# %% [markdown]
# ## Documentation
#
# - Any Number of Arguments With *args: https://docs.python.org/3/tutorial/controlflow.html#arbitrary-argument-lists

# %% [markdown]
# ## Any Number of Arguments With *args
#
# *Context: Inside the function, `numbers` is a real tuple holding whatever was passed — `*` is what tells Python to collect them, not a special variable name (any name works, `*args` is just the common convention).*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define total(*numbers) that returns sum(numbers)


# TODO: call it with 1, 2, 3 and print the result
# TODO: call it with 10, 20 and print the result
# TODO: call it with no arguments at all and print the result

# %% [markdown]
# ## Any Number of Named Arguments With **kwargs
#
# *Context: `details` is a real dict inside the function — `.items()` is the same dict-looping tool from the data-structures lesson, nothing new there.*
#
# *Complete the TODOs below as you code along.*
#
# *Input:*

# %%
# TODO: define describe_game(title, **details) that prints title,
# then loops over details.items() printing "  {key}: {value}"


# TODO: call it with "Chess", players=2, category="Strategy"
